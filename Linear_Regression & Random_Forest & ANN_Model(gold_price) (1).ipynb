# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\gpt\\AI_project\\gld_price_data.csv")
df
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
df.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
df.shape
# Out:
# (2290, 6)

# %%
 df.drop(['Date'], axis=1)
# Out:
#               SPX         GLD        USO      SLV   EUR/USD
# 0     1447.160034   84.860001  78.470001  15.1800  1.471692
# 1     1447.160034   85.570000  78.370003  15.2850  1.474491
# 2     1411.630005   85.129997  77.309998  15.1670  1.475492
# 3     1416.180054   84.769997  75.500000  15.0530  1.468299
# 4     1390.189941   86.779999  76.059998  15.5900  1.557099
# ...           ...         ...        ...      ...       ...
# 2285  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 5 columns]

# %%
df.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
df.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Date       False
# SPX        False
# GLD        False
# USO        False
# SLV        False
# EUR/USD    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
df.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
print('lenghth of dataset:',len(df))
# Out:
# lenghth of dataset: 2290

# %%
import matplotlib.pyplot as plt
df['GLD'].plot(figsize=(16,6))
plt.title('Linechart')
plt.xlabel('GLD')
plt.ylabel('frequency')
plt.show()

# %%
X = df.drop(['GLD','Date'], axis=1)
X
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
y=df['GLD']
y
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=100)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1603, 4)
# (687, 4)
# (1603,)
# (687,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [ 6.45917848e-03 -2.60304332e-01  3.15400852e+00 -1.01072425e+01]

# %%
print(regressor.intercept_)
# Out:
# 70.05117233974273

# %%
predicted=regressor.predict(X_test)
predicted
# Out:
# array([146.36201126,  97.15777142, 154.51570594, 156.03841188,
#        117.81293308, 124.86731979, 129.60508933, 147.2876883 ,
#        164.51435405, 168.91457421, 156.42432645, 137.88916799,
#        142.60356097, 120.59370042, 162.57987899, 118.01745174,
#        120.90763477, 173.4269081 ,  80.79552555, 115.16249169,
#        154.40001434, 122.38505361, 145.72974512, 119.28178739,
#        110.81640687,  94.73671195, 117.24512772, 120.07272048,
#        114.42040135, 122.65079741, 117.97705013, 157.9965146 ,
#         91.85207605, 166.20720122, 161.43848502, 120.46510358,
#        157.46319618, 126.21782419, 119.20857921, 118.00956665,
#        113.06214806, 111.68168357, 107.09667953, 143.45877417,
#        164.75097373, 106.33984874,  99.05264857,  99.0067395 ,
#         81.23520074, 110.54174138, 127.24622626, 122.93982765,
#        158.66067998, 113.67373788, 120.65905093,  90.84868107,
#        143.19071903, 117.61359506,  94.02399485, 120.45617244,
# ...

# %%
print(X_test)
# Out:
#               SPX        USO        SLV   EUR/USD
# 1140  1544.260010  32.939999  27.910000  1.297858
# 63    1372.540039  86.930000  17.950001  1.557802
# 945   1387.569946  39.439999  31.420000  1.318913
# 1067  1359.880005  31.930000  31.209999  1.278445
# 1339  1755.199951  34.740002  18.750000  1.352503
# ...           ...        ...        ...       ...
# 2061  2388.770020  10.240000  16.370001  1.086425
# 521   1115.050049  33.509998  17.870001  1.247894
# 1449  1920.209961  36.160000  19.049999  1.337238
# 334    976.289978  35.790001  13.520000  1.421202
# 650   1257.540039  38.709999  28.590000  1.307976
#
# [687 rows x 4 columns]

# %%
predicted.shape
# Out:
# (687,)

# %%
dframe=pd.DataFrame(y_test,predicted)
dframe
# Out:
#             GLD
# 146.362011  NaN
# 97.157771   NaN
# 154.515706  NaN
# 156.038412  NaN
# 117.812933  NaN
# ...         ...
# 123.465510  NaN
# 112.280050  NaN
# 119.609617  NaN
# 95.318673   NaN
# 145.050541  NaN
#
# [687 rows x 1 columns]

# %%
dfr=pd.DataFrame({'Actual Price':y_test,'Predicted Price':predicted})
dfr
# Out:
#       Actual Price  Predicted Price
# 1140    152.690002       146.362011
# 63       91.169998        97.157771
# 945     162.699997       154.515706
# 1067    165.880005       156.038412
# 1339    120.989998       117.812933
# ...            ...              ...
# 2061    120.389999       123.465510
# 521     116.629997       112.280050
# 1449    123.870003       119.609617
# 334      93.260002        95.318673
# 650     135.020004       145.050541
#
# [687 rows x 2 columns]

# %%
dfr.head(50)
# Out:
#       Actual Price  Predicted Price
# 1140    152.690002       146.362011
# 63       91.169998        97.157771
# 945     162.699997       154.515706
# 1067    165.880005       156.038412
# 1339    120.989998       117.812933
# 2025    117.580002       124.867320
# 1166    132.869995       129.605089
# 883     159.669998       147.287688
# 1042    173.610001       164.514354
# 755     150.559998       168.914574
# 1055    166.830002       156.424326
# 670     130.100006       137.889168
# 1013    155.130005       142.603561
# 1958    115.540001       120.593700
# 739     146.539993       162.579879
# 1633    113.889999       118.017452
# 2107    119.309998       120.907635
# 786     160.639999       173.426908
# 134      78.389999        80.795526
# 1641    113.779999       115.162492
# 1115    162.190002       154.400014
# 1426    126.989998       122.385054
# 960     154.470001       145.729745
# 1220    127.480003       119.281787
# 548     117.209999       110.816407
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(X_train,y_train)
print('train_accuracy:',train_accuracy)
test_accuracy=regressor.score(X_test,y_test)
print('test_accuracy:',test_accuracy)
# Out:
# train_accuracy: 0.8807789466016068
# test_accuracy: 0.8826421214186795

# %%
import math
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Mean Absolute Error: 6.181637430645267
# Mean Squared Error: 66.71418961870842
# Root Mean Squared Error: 8.167875465426025

# %%
graph=dfr.head(20)
graph
# Out:
#       Actual Price  Predicted Price
# 1140    152.690002       146.362011
# 63       91.169998        97.157771
# 945     162.699997       154.515706
# 1067    165.880005       156.038412
# 1339    120.989998       117.812933
# 2025    117.580002       124.867320
# 1166    132.869995       129.605089
# 883     159.669998       147.287688
# 1042    173.610001       164.514354
# 755     150.559998       168.914574
# 1055    166.830002       156.424326
# 670     130.100006       137.889168
# 1013    155.130005       142.603561
# 1958    115.540001       120.593700
# 739     146.539993       162.579879
# 1633    113.889999       118.017452
# 2107    119.309998       120.907635
# 786     160.639999       173.426908
# 134      78.389999        80.795526
# 1641    113.779999       115.162492

# %%
graph.plot(kind='bar')
plt.title('BarGraph')
plt.xlabel('Actual&prediceted price')
plt.ylabel('frequency')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
predicted=regressor.predict(X_test)
predicted
# Out:
# array([153.78760222,  92.84929863, 161.55360076, 165.67640128,
#        120.55230041, 118.43870128, 135.84679614, 154.38390139,
#        171.65540226, 148.27759908, 165.00290208, 131.00900055,
#        155.25780123, 113.51410086, 145.97639963, 115.39070117,
#        119.11139889, 170.95229829,  82.25079869, 113.98039933,
#        162.28910221, 127.05370007, 155.19200203, 127.02009824,
#        118.38819981,  90.29319959, 125.14769904, 124.33773724,
#        115.29890017, 123.53669953, 116.72610038, 167.61720016,
#         86.40899886, 150.18689801, 148.92290112, 120.21559987,
#        167.38789896, 119.57020099, 120.21889989, 123.65660028,
#        121.02459946, 118.03880016, 109.8866988 , 152.79730103,
#        153.40510013, 108.85039939,  93.9961009 ,  94.41080036,
#         72.94719994, 112.72119867, 135.35709814, 129.78579829,
#        168.01489845, 115.43470032, 125.11579977,  90.90330009,
#        150.66560003, 124.19519995,  92.37799951, 125.58829846,
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(X_train,y_train)
print('train_accuracy:',train_accuracy)
R_test_accuracy=regressor.score(X_test,y_test)
print('test_accuracy:',R_test_accuracy)
# Out:
# train_accuracy: 0.9982036191434742
# test_accuracy: 0.984682348774949

# %%
import matplotlib.pyplot as plt
linear_regression_accuracy =0.8826421214186796
random_forest_accuracy = 0.984682348774949
accuracy_scores = [linear_regression_accuracy, random_forest_accuracy]
model_names = ['Linear Regression', 'Random Forest Regression']
plt.bar(model_names, accuracy_scores)
plt.xlabel('Regression Models')
plt.ylabel('Test Accuracy')
plt.title('Comparison of Test Accuracy: Linear Regression vs Random Forest Regression')

plt.show()

# %% [markdown]
# ## ANN Model

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=100)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1603, 4)
# (687, 4)
# (1603,)
# (687,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.neural_network import MLPRegressor
ann_model=MLPRegressor(hidden_layer_sizes=(128,64,32),activation='relu',solver='lbfgs')
ann_model.fit(X_train,y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(128, 64, 32), solver='lbfgs')

# %%
y_pred=ann_model.predict(X_test)
y_pred
# Out:
# array([155.67200782,  91.92147686, 164.34381985, 166.36969161,
#        121.3297878 , 116.70561432, 136.0694834 , 156.38427808,
#        170.35215929, 146.62158773, 165.61214099, 131.36159471,
#        156.1771845 , 114.41662962, 144.3958531 , 114.46201337,
#        119.32080609, 175.16093976,  82.03256734, 113.78199053,
#        162.92856144, 128.98239724, 152.89609368, 125.32637407,
#        117.27839597,  88.32275344, 124.57590077, 122.44204257,
#        115.94021381, 122.97029369, 120.82936354, 168.2757586 ,
#         85.33720172, 151.46799149, 148.48863932, 120.63344874,
#        165.79353126, 118.8832138 , 121.09264867, 125.35990468,
#        120.41077116, 116.26390023, 109.81480939, 151.66421025,
#        155.85380209, 108.55087761,  96.55080673,  96.24960388,
#         75.30134164, 112.55878198, 134.56305921, 127.987087  ,
#        166.63028905, 116.01872737, 125.67082211,  90.15401149,
#        149.72047365, 123.81264085,  90.85394283, 125.49018385,
# ...

# %%
from sklearn.metrics import r2_score
r2_score=r2_score(y_test,y_pred)
print('R-square score:',r2_score)
# Out:
# R-square score: 0.9775977591588684

# %%
train_accuracy=ann_model.score(X_train,y_train)
print('train_accuracy:',train_accuracy)
test_accuracy=ann_model.score(X_test,y_test)
print('test_accuracy:',test_accuracy)
# Out:
# train_accuracy: 0.985000566386086
# test_accuracy: 0.9775977591588684

# %%
import math
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 2.16128169200226
# Mean Squared Error: 12.734955347063613
# Root Mean Squared Error: 3.568606919662575

# %%
import matplotlib.pyplot as plt
linear_regression_accuracy =0.8826421214186796
random_forest_accuracy = 0.984682348774949
ANN_model= 0.9775977591588684
accuracy_scores = [linear_regression_accuracy, random_forest_accuracy,ANN_model]
model_names = ['Linear Regression', 'Random Forest Regression','ANN_model']
plt.bar(model_names, accuracy_scores)
plt.xlabel('Regression Models')
plt.ylabel('Test Accuracy')
plt.title('Comparison of Test Accuracy: Linear Regression vs Random Forest Regression vs ANN_model')

plt.show()
